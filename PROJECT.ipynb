# %%
#INCLUDE NESESSARY MODULES AND LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#LOAD DATASET 
data=pd.read_csv("D:/ENTRY DSML/PYTHON/PROJECT/projectsource.csv.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.head
# Out:
# <bound method NDFrame.head of               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     161     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     167     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     158     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     154     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     176     203
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College        Salary
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     161     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     167     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     158     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     154     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     176     203
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College        Salary
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height        int32
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 374 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      374 non-null    object
#  1   Team      374 non-null    object
#  2   Number    374 non-null    int64
#  3   Position  374 non-null    object
#  4   Age       374 non-null    int64
#  5   Height    374 non-null    int32
#  6   Weight    374 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    374 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 27.8+ KB

# %%
#DATA_CLEANING
#1.HANDLING MISSING VALUES.
#1.1 CHECK FOR NULL VALUES
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#MISSING VALUES ARE PRESENT IN COLLEGE AND SALARY COLUMNS
print(data[["College","Salary"]])
# Out:
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 2 columns]

# %%
#1.2 REPLACE MISSING VALUE WITH MEAN VALUE
s_m=data["Salary"].mean()
print(s_m)
# Out:
# 4833969.545861297

# %%
data["Salary"].fillna(s_m,inplace = True)
data["Salary"]
# Out:
# C:\Users\Athul\AppData\Local\Temp\ipykernel_27264\545684497.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Salary"].fillna(s_m,inplace = True)
# 0      7.730337e+06
# 1      6.796117e+06
# 2      4.833970e+06
# 3      1.148640e+06
# 4      5.000000e+06
#            ...
# 453    2.433333e+06
# 454    9.000000e+05
# 455    2.900000e+06
# 456    9.472760e+05
# 457    9.472760e+05
# Name: Salary, Length: 458, dtype: float64

# %%
# 1.3REMOVE ROWS/COLUMNS THAT CONTAIN MISSING /NULL VALUES
data.dropna( inplace = True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  06-Jun     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
#2.HANDLING DUPLICATE VALUES
# 2.1CHECK FOR DUPLICATES 
data.duplicated()
#2.2 REMOVE DUPLICATES
data.drop_duplicates(inplace = True)# REMOVE DUPLICATE VALUES IF AVAILABLE
data.duplicated().sum()
# Out:
# 0

# %%
#CONFIRM ALL MISSING/NULL VALUES ARE REMOVED
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#np.random.randint(150,180,size = len(data))

# %%
#3 HANDLING INCONSISTENT DATA 
#CORRECT THE DATA IN THE "HEIGHT" COLUMN BY REPLACING IT WITH RANDOM NUMBERS BETWEEN 150 AND 180.
data["Height"] = np.random.randint(150,180,size = len(data))
data["Height"]
# Out:
# 0      175
# 1      161
# 2      178
# 3      164
# 6      167
#       ...
# 451    158
# 452    154
# 453    176
# 456    173
# 457    154
# Name: Height, Length: 374, dtype: int32

# %%
# Group the data by height and count the frequency
height_counts = data['Height'].value_counts()
# Create a bar chart
plt.figure(figsize=(10,6))
plt.bar(height_counts.index, height_counts.values, edgecolor='black',color=["orange","yellow","green","blue","red"])
# Set title and labels
plt.title('Height Distribution')
plt.xlabel('Height (CM)')
plt.ylabel('Frequency')
# Show the plot
plt.show()

# %%
#DATA ANALYSIS
#**********1. DETERMINE THE DISTRIBUTION OF EMPLOYEES ACROSS EACH TEAM AND CALCULATE THE PERCENTAGE SPLIT RELATIVE TO THE TOTAL NUMBER OF EMPLOYEES.

# %%
#DETERMINE THE DISTRIBUTION OF EMPLOYEES ACROSS EACH TEAM
team_distribution=data["Team"].value_counts().sort_values(ascending=False)
#value_counts()->count the number of occurrences of each unique value in a Series (column) of a DataFrame.
#sort_values(ascending=False)->sort values in descending order
print(team_distribution)
# Out:
# Team
# Memphis Grizzlies         17
# New Orleans Pelicans      16
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Detroit Pistons           15
# Milwaukee Bucks           14
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Phoenix Suns              13
# Brooklyn Nets             13
# Sacramento Kings          13
# Boston Celtics            13
# Charlotte Hornets         13
# Washington Wizards        13
# Golden State Warriors     12
# Chicago Bulls             12
# Los Angeles Lakers        12
# Indiana Pacers            12
# Cleveland Cavaliers       12
# Dallas Mavericks          12
# Houston Rockets           11
# San Antonio Spurs         11
# Atlanta Hawks             11
# Miami Heat                11
# New York Knicks           11
# Utah Jazz                 11
# Orlando Magic             10
# Toronto Raptors           10
# Denver Nuggets             9
# Minnesota Timberwolves     9
# Name: count, dtype: int64

# %%
#CALCULATE THE PERCENTAGE SPLIT RELATIVE TO THE TOTAL NUMBER OF EMPLOYEES
total_employees = len(data)#len()-returns the number of items in an object.object can be a string, list, tuple, dictionary, set, or any collection.
print(total_employees)
# Out:
# 374

# %%
# CALCULATE THE PERCENTAGE SPLIT FOR EACH TEAM
team_percentage = (team_distribution / total_employees) * 100
#print(team_percentage )
print(team_percentage.round(2) )# round a number to the nearest integer or to a specified number of decimal places.
# Out:
# Team
# Memphis Grizzlies         4.55
# New Orleans Pelicans      4.28
# Portland Trail Blazers    4.01
# Philadelphia 76ers        4.01
# Detroit Pistons           4.01
# Milwaukee Bucks           3.74
# Oklahoma City Thunder     3.74
# Los Angeles Clippers      3.74
# Phoenix Suns              3.48
# Brooklyn Nets             3.48
# Sacramento Kings          3.48
# Boston Celtics            3.48
# Charlotte Hornets         3.48
# Washington Wizards        3.48
# Golden State Warriors     3.21
# Chicago Bulls             3.21
# Los Angeles Lakers        3.21
# Indiana Pacers            3.21
# Cleveland Cavaliers       3.21
# Dallas Mavericks          3.21
# Houston Rockets           2.94
# San Antonio Spurs         2.94
# Atlanta Hawks             2.94
# Miami Heat                2.94
# New York Knicks           2.94
# Utah Jazz                 2.94
# Orlando Magic             2.67
# Toronto Raptors           2.67
# Denver Nuggets            2.41
# Minnesota Timberwolves    2.41
# ...

# %%
# Create a bar chart
plt.figure(figsize=(10,6))
plt.bar(team_percentage.index,team_percentage.values)
plt.xlabel('Team')
plt.ylabel('Percentage of Employees')
plt.title('Distribution of Employees by Team')
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(10,6))
plt.pie(team_distribution.values, labels=team_distribution.index)
plt.title('Distribution of Employees by Team')
plt.show()

# %%
#*******************2. SEGREGATE EMPLOYEES BASED ON THEIR POSITIONS WITHIN THE COMPANY.

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
#GET THE UNIQUE POSITIONS IN THE DATASET
positions = data["Position"].unique()#return the unique values in a Series (column) of a DataFrame.
print(positions)
# Out:
# ['PG' 'SF' 'SG' 'PF' 'C']

# %%
# METHOD1
#CREATE A DICTIONARY TO STORE THE SEGREGATED EMPLOYEES
segregated_employees = {}

# %%
# LOOP THROUGH EACH POSITION ['PG' 'SF' 'SG' 'PF' 'C'] AND SEGREGATE THE EMPLOYEES
for position in positions:
    segregated_employees[position] = data[data["Position"] == position]

# %%
#segregated_employees["SG"]
#data[data["Position"] == "SG"]

# %%
#DISPLAY DICTIONARY segregated_employees
#segregated_employees

# %%
#The items() method in a dictionary returns a view object that displays a list of all the key-value pairs in the dictionary
#segregated_employees.items()

# %%
#PRINT THE SEGREGATED EMPLOYEES
for position, employees in segregated_employees.items():
    print(f"Employees with Position: {position} are ")
    print("___________________________________________\n")
    print(employees['Name'].to_string(index=False))  # Print the 'Name' column
    print("\n*******************************************************\n")
# Out:
# Employees with Position: PG are
# ___________________________________________
#
#           Avery Bradley
#            Terry Rozier
#            Marcus Smart
#           Isaiah Thomas
#            Jarrett Jack
#            Shane Larkin
#            Donald Sloan
#            Jerian Grant
#           Isaiah Canaan
#        Kendall Marshall
#          T.J. McConnell
#               Ish Smith
#             Cory Joseph
#              Kyle Lowry
#            Delon Wright
#           Stephen Curry
#              Chris Paul
#           Austin Rivers
#         Jordan Clarkson
#        D'Angelo Russell
#            Eric Bledsoe
#          Brandon Knight
#            Phil Pressey
#            Ronnie Price
#         Darren Collison
#             Rajon Rondo
#            Aaron Brooks
#            Derrick Rose
#     Matthew Dellavedova
#            Kyrie Irving
#             Mo Williams
#             Steve Blake
#           Lorenzo Brown
#       Spencer Dinwiddie
#          Reggie Jackson
# ...

# %%
# METHOD2
#USING GROUP BY segregated_employees_grp = data.groupby('Position')

# %%
# Print the segregated employees
for name, group in segregated_employees_grp:
    print(f"Position: {name}")
    print(group['Name'])
    print("\n")
# Out:
# Position: C
# 7             Kelly Olynyk
# 10         Jared Sullinger
# 14            Tyler Zeller
# 23             Brook Lopez
# 27              Henry Sims
# 38             Robin Lopez
# 49             Joel Embiid
# 56           Jahlil Okafor
# 78            Andrew Bogut
# 81            Festus Ezeli
# 88       Marreese Speights
# 91            Cole Aldrich
# 98          DeAndre Jordan
# 107            Tarik Black
# 111            Roy Hibbert
# 117           Robert Sacre
# 128               Alex Len
# 135          Alan Williams
# 141    Willie Cauley-Stein
# 143       DeMarcus Cousins
# 147           Kosta Koufos
# 162            Joakim Noah
# 173             Sasha Kaun
# 179       Tristan Thompson
# 181           Joel Anthony
# 182            Aron Baynes
# 188         Andre Drummond
# 201            Jordan Hill
# 220            Greg Monroe
# 224          Miles Plumlee
# 234           JaVale McGee
# 296            Matt Bonner
# 298             Tim Duncan
# 312             Al Horford
# ...

# %%
position_counts = data['Position'].value_counts()
plt.figure(figsize=(10,6))
plt.bar(position_counts.index, position_counts.values)
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Position')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to fit rotated labels
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.pie(position_counts.values, labels=position_counts.index, autopct='%1.1f%%')
plt.title('Employee Distribution by Position')
plt.show()

# %%
#************3.IDENTIFY THE PREDOMINANT AGE GROUP AMONG EMPLOYEES.************************
data["Age"]
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 6      21
#        ..
# 451    26
# 452    20
# 453    26
# 456    26
# 457    25
# Name: Age, Length: 374, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x = "Age",data = data,hue  ="Age",palette  ="pastel")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
data["Age"].unique()
# Out:
# array([25, 27, 22, 21, 24, 20, 26, 28, 32, 23, 30, 33, 37, 29, 31, 36, 38,
#        19, 35, 34, 39, 40], dtype=int64)

# %%
data["Age"].nunique()
# Out:
# 22

# %%
predominant_age_group = age_groups.idxmax()
print(predominant_age_group)
# Out:
# 25

# %%
#np.where(condition, value_if_true, value_if_false)
# condition: A boolean array or a condition that evaluates to a boolean array.
# value_if_true: The value to return when the condition is true.
#value_if_false: The value to return when the condition is false.
data["Age Group"] = np.where(data['Age'] < 25, '20-24',
                                         np.where(data['Age'] < 35, '25-34',
                                                   np.where(data['Age'] < 45, '35-44',
                                                             np.where(data['Age'] < 55, '45-54', '55+'))))

# %%
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     161     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     167     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     158     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     154     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     176     203
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College        Salary Age Group
# ...

# %%
Age_group_status=data["Age Group"].value_counts()
print(Age_group_status)
# Out:
# Age Group
# 25-34    218
# 20-24    131
# 35-44     25
# Name: count, dtype: int64

# %%
Age_group_status=data["Age Group"].value_counts().sort_values(ascending=False).head(1)
print(Age_group_status)
# Out:
# Age Group
# 25-34    218
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Age Group",data = data,palette = "magma",hue = "Age Group")
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
age_group_counts = data['Age Group'].value_counts()
plt.figure(figsize=(10,6))
plt.pie(age_group_counts.values, labels=age_group_counts.index, autopct='%1.1f%%')
plt.title('Employee Distribution by Age Group')
plt.show()

# %%
#******************4. DISCOVER WHICH TEAM AND POSITION HAVE THE HIGHEST SALARY EXPENDITURE.****************************

# %%
print(data["Salary"].unique())
# Out:
# [ 7730337.         6796117.         4833969.5458613  1148640.
#   1170960.         2165160.         1824360.         3431040.
#   2569260.         6912869.         3425510.         1749840.
#   2616975.          845059.         1500000.         1335480.
#   6300000.          134215.        19689000.         1140240.
#    947276.          981348.        11235955.         8000000.
#   1635476.        22875000.         1572360.        12650000.
#   3750000.         1636842.         4000000.          167406.
#   1000000.         4626960.         1074169.         6500000.
#   2144772.          525093.         3457800.         4582680.
#   2869440.        13600000.        10050000.         2500000.
#   7000000.        12000000.         6268675.          650000.
#   3553917.          245177.         1509360.         3873398.
#  13800000.        11370786.         2008748.        14260870.
#  11710456.         1131960.         1270964.         3815000.
# ...

# %%
spending_salary = data.groupby(['Team','Position'])['Salary'].sum()
spending_salary.idxmax()
#find maxmum salary
total_salary = df1.groupby(["Team","Position"])["Salary"].sum()
max_spending = total_salary.idxmax()
max_spending_salary = total_salary.max()
print(f"The team and position with the highest spending is:\n Team: {max_spending[0]}\n position: {max_spending[1]} \n with a total salary of {max_spending_salary}.")

# %%
# Group the data by team and position
grouped_salary = data.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
grouped_salary
# Out:
#                    Team Position      Salary
# 0         Atlanta Hawks        C  12000000.0
# 1         Atlanta Hawks       PF  23952268.0
# 2         Atlanta Hawks       PG   8000000.0
# 3         Atlanta Hawks       SF   2000000.0
# 4         Atlanta Hawks       SG  10431032.0
# ..                  ...      ...         ...
# 138  Washington Wizards        C    273038.0
# 139  Washington Wizards       PF  11300000.0
# 140  Washington Wizards       PG  18022415.0
# 141  Washington Wizards       SF  11158800.0
# 142  Washington Wizards       SG  11356992.0
#
# [143 rows x 3 columns]

# %%
grouped_salary = data.groupby(['Team', 'Position'])['Salary'].sum()
grouped_salary.idxmax()
# Out:
# ('Miami Heat', 'PF')

# %%
max_salary_expenditure = grouped_salary.loc[grouped_salary['Salary'].idxmax()]

print(f'Team with highest salary expenditure: {max_salary_expenditure["Team"]}')
print(f'Position with highest salary expenditure: {max_salary_expenditure["Position"]}')
print(f'Highest salary expenditure: {max_salary_expenditure["Salary"]:}')
# Out:
# Team with highest salary expenditure: Miami Heat
# Position with highest salary expenditure: PF
# Highest salary expenditure: 30591395.0

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(y = "Salary",x="Team",hue = "Position",data = data)
plt.ylabel("Salary")
plt.xlabel("Team")
plt.title("Position vs Team with salary")
plt.xticks(rotation=45)
plt.show()

# %%
#***********5.INVESTIGATE IF THERE'S ANY CORRELATION BETWEEN AGE AND SALARY, AND REPRESENT IT VISUALLY.********************

# %%
employee = data[["Age","Salary"]]
employee
# Out:
#               Name  Age        Salary
# 0    Avery Bradley   25  7.730337e+06
# 1      Jae Crowder   25  6.796117e+06
# 2     John Holland   27  4.833970e+06
# 3      R.J. Hunter   22  1.148640e+06
# 6    Jordan Mickey   21  1.170960e+06
# ..             ...  ...           ...
# 451  Chris Johnson   26  9.813480e+05
# 452     Trey Lyles   20  2.239800e+06
# 453   Shelvin Mack   26  2.433333e+06
# 456    Jeff Withey   26  9.472760e+05
# 457       Priyanka   25  9.472760e+05
#
# [374 rows x 3 columns]

# %%
correlation = employee['Age'].corr(employee['Salary'])
print(f'Correlation between Age and Salary: {correlation:.2f}')
#[ 0.9-1.0: Very strong positive correlation,- 0.7-0.89: Strong positive correlation,- 0.5-0.69: Moderate positive correlation
# 0.3-0.49: Weak positive correlation,- 0.0-0.29: Very weak positive correlation,- -0.3 to -0.49: Weak negative correlation
# -0.5 to -0.69: Moderate negative correlation,- -0.7 to -0.89: Strong negative correlation- -0.9 to -1.0: Very strong negative correlation]
# Out:
# Correlation between Age and Salary: 0.16

# %%
sns.scatterplot(x="Age" ,y= "Salary",data= data)
plt.ylabel("Salary")
plt.xlabel("Age")
plt.title("correlation b/w Salary and Age")
plt.show()
